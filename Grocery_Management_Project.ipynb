# %%
Name=str(input("Enter Your Name: "))
print("Welcome to My Shop Mrs/Ms: ",Name)
Total=0
itemPrice=[]
n="d"
while n!="q":
    print("Anything you want ",Name)
    print("Press 'q' Goto Menu")
    n=str(input("'Say Yes or y'  : ")).lower()
    if n == 'yes' or n=='y':
        print('''
            1.Coffee
            2.Drinks
        ''')
        choose=int(input("Please You Want : "))
        if choose==1:
            q=True
            while q:
                
                print('''
                    welCome to Coffe:
                    1.Types of Coffee
                    2.Add
                    3.Exit
                ''')
                a=int(input("Enter Your Choose : "))
                if a == 1:
                    dict1={"Espresso":116,"ClassicFilterCoffee":126,"Macchiato":142,"CafeAmericano":142,"CafeMocha":163}
                    d=1
                    for i,j in dict1.items():
                        print("\t",d,".",i,"Rs.",j)
                        d+=1
                if a == 2:
                    q=True
                    while q:
                        print("Press The 'q' Goto Menu")
                        item=str(input('Enter Your Oder Name'))
                        if item in dict1.keys():
                            qnt=int(input("Enter Your Quantity"))
                            price=float(dict1[item]*qnt)
                            itemPrice.append((item,qnt,price))
                            Total+=price
                        elif item=='q':
                            q=False
                        else:
                            print('Your Order is unavailable')
        
                else:
                    print('Enter Valid option')
        elif choose==2:
            q=True
            while q:
                
                print('''
                    welCome to Drinks:
                    1.Types of Drinks
                    2.Add
                    3.Exit
                ''')
                a=int(input("Enter Your Choose : "))
                if a == 1:
                    dict2={"Thumsup":20,"pepsi":30,"sprite":50,"maaja":35,"cococola":45}
                    d=1
                    for i,j in dict2.items():
                        print("\t",d,".",i,"Rs.",j)
                        d+=1
                if a == 2:
                    q=True
                    while q:
                        print("Press The 'q' Goto Menu")
                        item=str(input('Enter Your Oder Name'))
                        if item in dict2.keys():
                            qnt=int(input("Enter Your Quantity"))
                            price=float(dict2[item]*qnt)
                            itemPrice.append((item,qnt,price))
                            Total+=price
                        elif item=='q':
                            q=False
        elif choose == 'q':
            q=False
        else:
            print("Invalid Choose")
    elif option == 'no' or option=='n':
        q=option
        q=False
    else:
        print("Thank For Viziting My Shop")
print("outside loop")
# Out:
# Enter Your Name: Lavanya
# Welcome to My Shop Mrs/Ms:  Lavanya
# Anything you want  Lavanya
# Press 'q' Goto Menu
# 'Say Yes or y'  : y
#
#             1.Coffee
#             2.Drinks
#
# Please You Want : 1
#
#                     welCome to Coffe:
#                     1.Types of Coffee
#                     2.Add
#                     3.Exit
#
# Enter Your Choose : 1
# 	 1 . Espresso Rs. 116
# 	 2 . ClassicFilterCoffee Rs. 126
# 	 3 . Macchiato Rs. 142
# 	 4 . CafeAmericano Rs. 142
# 	 5 . CafeMocha Rs. 163
# Enter Valid option
#
#                     welCome to Coffe:
#                     1.Types of Coffee
#                     2.Add
#                     3.Exit
#
# Enter Your Choose : 2
# Press The 'q' Goto Menu
# Enter Your Oder NameEspresso
# Enter Your Quantity2
# Press The 'q' Goto Menu
# Enter Your Oder NameMacchiato
# Enter Your Quantity1
# Press The 'q' Goto Menu
# Enter Your Oder NameCafeMocha
# Enter Your Quantity3
# Press The 'q' Goto Menu
# Enter Your Oder Nameq
# ...

# %%
print(70*'-')
print('''
                          VIRAT SUPER MARKET
      ''')
print(70*'-')
print("Hai,Mrs/Ms:",Name,"Your Total items list and Price")
print(50*'-')
for j in itemPrice:
        print('Item:',j[0],'\tQuntity:',j[1],'\t Price:',j[2])
print(70*'=')
print("Your Payble Amount is:",Total)
print(70*'=')
# Out:
# ----------------------------------------------------------------------
#
#                           VIRAT SUPER MARKET
#
# ----------------------------------------------------------------------
# Hai,Mrs/Ms: Lavanya Your Total items list and Price
# --------------------------------------------------
# Item: Espresso 	Quntity: 2 	 Price: 232.0
# Item: Macchiato 	Quntity: 1 	 Price: 142.0
# Item: CafeMocha 	Quntity: 3 	 Price: 489.0
# Item: Thumsup 	Quntity: 2 	 Price: 40.0
# Item: sprite 	Quntity: 1 	 Price: 50.0
# Item: cococola 	Quntity: 3 	 Price: 135.0
# ...
# Your Payble Amount is: 1088.0
# ...
